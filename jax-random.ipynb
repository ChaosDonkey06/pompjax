# %%
import jax.random as rran

# %%
import jax.numpy as np
import jax

loww = -1
upp  = 1

# Generate a key
key = rran.PRNGKey(0)
# Sample from a uniform distribution
sample_unifform  = rran.uniform(key, shape=(1, 5000), minval=loww, maxval=upp)

# Generate a key
key = rran.PRNGKey(1)


mean = 50
sd   = 5

# Sampel from a truncated normal distribution

# %%
θ_min = np.array([20, 10, 5])
θ_max = np.array([40, 30, 10])
μ     = np.array([30, 20, 7.5])
σ2    = np.diag(np.array([1, 1, 1]))

sample_params_normal(key, θ_min, θ_max, μ, σ2, m=300)
# Out:
# DeviceArray([[[30.629807 , 19.57059  ,  9.385614 ],
#               [29.004171 , 19.198269 ,  7.5523267],
#               [30.215458 , 20.94537  ,  7.2380376],
#               ...,
#               [30.505066 , 19.742159 ,  8.634034 ],
#               [28.52647  , 19.866985 ,  7.045109 ],
#               [27.853582 , 21.985348 ,  6.8196564]],
#
#              [[32.043194 , 17.83963  ,  6.9536886],
#               [29.426405 , 22.32049  ,  8.89039  ],
#               [29.991272 , 20.793253 ,  7.5345783],
#               ...,
#               [31.357424 , 21.556278 ,  7.2203116],
#               [30.493608 , 21.005278 ,  7.3715615],
#               [29.19212  , 19.930784 ,  7.636096 ]],
#
#              [[30.656    , 20.809353 ,  9.059887 ],
#               [29.010035 , 20.268858 ,  9.281046 ],
#               [30.957846 , 18.493954 ,  8.333582 ],
#               ...,
#               [29.601372 , 18.5629   ,  7.754757 ],
#               [30.547249 , 19.710642 ,  7.2146907],
#               [30.161068 , 18.90234  ,  6.811089 ]]], dtype=float32)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

sns.kdeplot(ax=ax[0], data=np.squeeze(sample_unifform) , bw = 0.5 , fill = True)
sns.kdeplot(ax=ax[1], data=np.squeeze(sample_truncated) , bw = 0.5 , fill = True)
# Out:
# /var/folders/7p/jp6xqkvn5wb6ddl1fn0bhs980000gn/T/ipykernel_50876/3073985846.py:6: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(ax=ax[0], data=np.squeeze(sample_unifform) , bw = 0.5 , fill = True)
# /var/folders/7p/jp6xqkvn5wb6ddl1fn0bhs980000gn/T/ipykernel_50876/3073985846.py:7: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(ax=ax[1], data=np.squeeze(sample_truncated) , bw = 0.5 , fill = True)
# <AxesSubplot: ylabel='Density'>
